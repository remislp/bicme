# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
import scipy.io as sio

# %%
from bicme.tests.case_normal import CaseNormal
from bicme.samplers import MWGSampler
from bicme.samplers import RosenthalAdaptiveSampler
from bicme.proposals import RWMHProposal
from bicme.display import quick_display
from bicme.display import DisplayResults

# %%
mat1 = sio.loadmat('../../Tests/Data/NormData.mat')
data = np.array(mat1['data']).flatten()
np.random.seed(1)
cn = CaseNormal(data)

# %% [markdown]
# ##### Run: sampler- Metropolis_within_Gibbs sampler with scaling during burn-in; proposal-  random-walk Metropoli-Hastings.

# %%
X0 = [2, 10]
N = 10000 # samples required
M = 1000 # notify every #
lag = 50 # adjustment lag
# Initialise Proposer
proposer = RWMHProposal(cn.logPosterior, verbose=True)
# Initialise Sampler
sampler = MWGSampler(samples_draw=N, notify_every=M, 
                     burnin_fraction=0.5, burnin_lag=lag,
                     model=cn.logPosterior, 
                     proposal=proposer.propose_block,
                     verbose=True)  
sampler.acceptance_limits = [0.3, 0.7]
sampler.scale = 0.5
# Sample
np.random.seed(1)
S = sampler.sample_block(X0)
# Out:
# Sampler initialised...
# Iteration 50; Acceptance: 0.400000; Scale factor 1.000000: not changed
# Iteration 100; Acceptance: 0.380000; Scale factor 1.000000: not changed
# Iteration 150; Acceptance: 0.220000; Scale factor 0.500000: decreased
# Iteration 200; Acceptance: 0.440000; Scale factor 0.500000: not changed
# Iteration 250; Acceptance: 0.300000; Scale factor 0.500000: not changed
# Iteration 300; Acceptance: 0.420000; Scale factor 0.500000: not changed
# Iteration 350; Acceptance: 0.280000; Scale factor 0.250000: decreased
# Iteration 400; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 450; Acceptance: 0.600000; Scale factor 0.250000: not changed
# Iteration 500; Acceptance: 0.660000; Scale factor 0.250000: not changed
# Iteration 550; Acceptance: 0.420000; Scale factor 0.250000: not changed
# Iteration 600; Acceptance: 0.440000; Scale factor 0.250000: not changed
# Iteration 650; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 700; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 750; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 800; Acceptance: 0.640000; Scale factor 0.250000: not changed
# Iteration 850; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 900; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 950; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 1000; Acceptance: 0.540000; Scale factor 0.250000: not changed
# 10.0 %
# Iteration 1050; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 1100; Acceptance: 0.640000; Scale factor 0.250000: not changed
# Iteration 1150; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 1200; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 1250; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 1300; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 1350; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 1400; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 1450; Acceptance: 0.620000; Scale factor 0.250000: not changed
# Iteration 1500; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 1550; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 1600; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 1650; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 1700; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 1750; Acceptance: 0.440000; Scale factor 0.250000: not changed
# Iteration 1800; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 1850; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 1900; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 1950; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 2000; Acceptance: 0.480000; Scale factor 0.250000: not changed
# 20.0 %
# Iteration 2050; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 2100; Acceptance: 0.400000; Scale factor 0.250000: not changed
# Iteration 2150; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 2200; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 2250; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 2300; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 2350; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 2400; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 2450; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 2500; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 2550; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 2600; Acceptance: 0.440000; Scale factor 0.250000: not changed
# Iteration 2650; Acceptance: 0.620000; Scale factor 0.250000: not changed
# Iteration 2700; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 2750; Acceptance: 0.620000; Scale factor 0.250000: not changed
# Iteration 2800; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 2850; Acceptance: 0.620000; Scale factor 0.250000: not changed
# Iteration 2900; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 2950; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 3000; Acceptance: 0.500000; Scale factor 0.250000: not changed
# 30.0 %
# Iteration 3050; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 3100; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 3150; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 3200; Acceptance: 0.640000; Scale factor 0.250000: not changed
# Iteration 3250; Acceptance: 0.400000; Scale factor 0.250000: not changed
# Iteration 3300; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 3350; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 3400; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 3450; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 3500; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 3550; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 3600; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 3650; Acceptance: 0.440000; Scale factor 0.250000: not changed
# Iteration 3700; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 3750; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 3800; Acceptance: 0.560000; Scale factor 0.250000: not changed
# Iteration 3850; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 3900; Acceptance: 0.620000; Scale factor 0.250000: not changed
# Iteration 3950; Acceptance: 0.620000; Scale factor 0.250000: not changed
# Iteration 4000; Acceptance: 0.600000; Scale factor 0.250000: not changed
# 40.0 %
# Iteration 4050; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 4100; Acceptance: 0.400000; Scale factor 0.250000: not changed
# Iteration 4150; Acceptance: 0.480000; Scale factor 0.250000: not changed
# Iteration 4200; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 4250; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 4300; Acceptance: 0.420000; Scale factor 0.250000: not changed
# Iteration 4350; Acceptance: 0.400000; Scale factor 0.250000: not changed
# Iteration 4400; Acceptance: 0.440000; Scale factor 0.250000: not changed
# Iteration 4450; Acceptance: 0.460000; Scale factor 0.250000: not changed
# Iteration 4500; Acceptance: 0.520000; Scale factor 0.250000: not changed
# Iteration 4550; Acceptance: 0.540000; Scale factor 0.250000: not changed
# Iteration 4600; Acceptance: 0.600000; Scale factor 0.250000: not changed
# Iteration 4650; Acceptance: 0.500000; Scale factor 0.250000: not changed
# Iteration 4700; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 4750; Acceptance: 0.600000; Scale factor 0.250000: not changed
# Iteration 4800; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 4850; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 4900; Acceptance: 0.660000; Scale factor 0.250000: not changed
# Iteration 4950; Acceptance: 0.580000; Scale factor 0.250000: not changed
# Iteration 5000; Acceptance: 0.500000; Scale factor 0.250000: not changed
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# 100.0 %

# %%
print('max posterior = ', max(S.posteriors))
imax = np.where(S.posteriors == S.posteriors.max())[0][0]
print('imax=', imax)
print('MEP pars=', S.samples[:, imax])
# Out:
# max posterior =  -1118.18420559
# imax= 4067
# MEP pars= [-0.25576396  9.77513729]

# %%
quick_display(S, burnin=N//2)

# %%
display = DisplayResults(S, burnin=S.N//2, names=['mu', 'sigma'])
#display.normalised = True
#display.show_labels = False
display.chains()

# %%
display.distributions()

# %%
display.corner()

# %%
display.autocorrelations()
