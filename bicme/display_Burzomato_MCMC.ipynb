# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import time
import math
import numpy as np

# %%
from display import DisplayResults

# %% [markdown]
# ##### Data

# %%
fname = 'F:/MCMC/datasets/GlyR_Burzomato_MCMC_MWG.csv'
par_names = ['alpha1', 'beta1', 'alpha2', 'beta2', 'alpha3', 'beta3',
             '2kf(-2)', 'gamma1', 'kf(+3)', 'gamma2', 'delta2', 'delta3', 
             'k(+3)', 'k(-1)', 'logLik']

# %%
#np.savetxt('AChR_MCMC_MWG.csv', S, delimiter=',')
S = np.loadtxt(fname, delimiter=',')

# %%
Lmax = S[-1].max()
print('Lmax = ', Lmax)
imax = np.where(S[-1] == S[-1].max())[0][0]
print('imax = ', imax)
print('pars=', S[:, imax])
# Out:
# Lmax =  264177.303462
# imax =  844802
# pars= [  4.11171100e+03   8.37516168e+02   1.38328121e+03   5.92495639e+03
#    3.12604167e+03   9.89074588e+04   1.80709759e+03   4.00326659e+07
#    9.39646023e+02   3.57685803e+02   1.86996052e+03   1.77744182e+03
#    9.14912885e+05   2.73045214e+02   2.64177303e+05]

# %%
display = DisplayResults(S, burnin=int(len(S[-1])/2), names=par_names)
#display.normalised = True
#display.show_labels = False
display.chains()

# %%
display.distributions()

# %%
display.corner()

# %%
display.autocorrelations()

# %%
#display.correlations(3, 1)
